# %%
import pandas as pd #matplotlib kutuphanesi lazim oldugunda cagirilacaktir.

# %%
df = pd.read_csv('MovieRatings.csv') #dosya okuma
#print(df)

# %%
df.shape #satir ve sutün sayisi
# Out:
# (559, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  541 non-null    float64
#  3   Audience Ratings %         546 non-null    float64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 26.3+ KB

# %%
df.head(559) #print list
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                       87.0
# 1              10,000 B.C.  Adventure                        9.0
# 2               12 Rounds      Action                       30.0
# 3                127 Hours  Adventure                       93.0
# 4                17 Again      Comedy                       55.0
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                       26.0
# 555        Youth in Revolt     Comedy                       68.0
# 556                 Zodiac   Thriller                       89.0
# 557            Zombieland      Action                       90.0
# 558              Zookeeper     Comedy                       14.0
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                   NaN                   8             2009
# 1                  44.0                 105             2008
# ...

# %%
df.dropna(subset = ['Rotten Tomatoes Ratings %','Audience Ratings %'], inplace=True) #NaN ogeler burada, cikaralim.

# %%
df.shape #satir ve sutün sayisi
# Out:
# (535, 6)

# %%
df.nlargest(1, 'Rotten Tomatoes Ratings %') #en yuksek Rotten Tomatoes Ratings % degerini alan film
# Out:
#            Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 387  The Artist  Drama                       97.0                91.0
#
#      Budget (million $)  Year of release
# 387                  16             2011

# %%
df.nlargest(1, 'Audience Ratings %') #en yuksek Audience Ratings % degerini alan film
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 406  The Dark Knight  Thriller                       94.0                96.0
#
#      Budget (million $)  Year of release
# 406                 185             2008

# %%
df.nlargest(10, 'Rotten Tomatoes Ratings %') #en yuksek Rotten Tomatoes Ratings % degerini alan 10 film
# Out:
#                        Film      Genre  Rotten Tomatoes Ratings %  \
# 387              The Artist      Drama                       97.0
# 431        The Hurt Locker       Drama                       97.0
# 455             The Muppets     Comedy                       97.0
# 506               True Grit  Adventure                       96.0
# 249               Moneyball      Drama                       95.0
# 275  No Country for Old Men      Drama                       95.0
# 26             An Education      Drama                       94.0
# 196                Iron Man     Action                       94.0
# 207                    Juno     Comedy                       94.0
# 362              Star Trek      Action                       94.0
#
#      Audience Ratings %  Budget (million $)  Year of release
# 387                91.0                  16             2011
# 431                83.0                  15             2008
# ...

# %%
df.nlargest(10, 'Audience Ratings %') #en yuksek Audience Ratings % degerini alan 10 film
# Out:
#                      Film     Genre  Rotten Tomatoes Ratings %  \
# 406       The Dark Knight  Thriller                       94.0
# 9                   50/50    Comedy                       93.0
# 190             Inception    Action                       86.0
# 530               Warrior    Action                       83.0
# 33                Avatar     Action                       83.0
# 196              Iron Man    Action                       94.0
# 362            Star Trek     Action                       94.0
# 387            The Artist     Drama                       97.0
# 394  The Bourne Ultimatum  Thriller                       93.0
# 428              The Help     Drama                       75.0
#
#      Audience Ratings %  Budget (million $)  Year of release
# 406                96.0                 185             2008
# 9                  93.0                   8             2011
# 190                93.0                 160             2010
# ...

# %%
SubsetComedy = df[df["Genre"] == "Comedy"] #Sadece türü komedi olan filmleri ayiralim.

# %%
SubsetComedy.head(164) #Türü komedi olan filmleri listeleyelim.
# Out:
#                                    Film   Genre  Rotten Tomatoes Ratings %  \
# 4                             17 Again   Comedy                       55.0
# 6                            27 Dresses  Comedy                       40.0
# 8                    30 Minutes or Less  Comedy                       43.0
# 9                                 50/50  Comedy                       93.0
# 14    A Very Harold and Kumar Christmas  Comedy                       72.0
# ..                                  ...     ...                        ...
# 552       You Don't Mess with the Zohan  Comedy                       36.0
# 553  You Will Meet a Tall Dark Stranger  Comedy                       43.0
# 554                       Your Highness  Comedy                       26.0
# 555                     Youth in Revolt  Comedy                       68.0
# 558                           Zookeeper  Comedy                       14.0
#
#      Audience Ratings %  Budget (million $)  Year of release
# ...

# %%
SubsetComedy.nlargest(164, 'Rotten Tomatoes Ratings %') #Komedi filmlerini Rotten Tomatoes Ratings % değerlerine göre silaralayalim.
# Out:
#                        Film   Genre  Rotten Tomatoes Ratings %  \
# 455             The Muppets  Comedy                       97.0
# 440  The Kids Are All Right  Comedy                       94.0
# 207                    Juno  Comedy                       94.0
# 9                     50/50  Comedy                       93.0
# 113               Enchanted  Comedy                       93.0
# ..                      ...     ...                        ...
# 200           Jack and Jill  Comedy                        4.0
# 242       Meet the Spartans  Comedy                        2.0
# 93           Disaster Movie  Comedy                        2.0
# 114              Epic Movie  Comedy                        2.0
# 80           Daddy Day Camp  Comedy                        1.0
#
#      Audience Ratings %  Budget (million $)  Year of release
# 455                87.0                  45             2011
# 440                72.0                   4             2010
# ...

# %%
df['Genre'].unique()
# Out:
# array(['Adventure', 'Action', 'Comedy', 'Horror', 'Drama', 'Romance',
#        'Thriller'], dtype=object)

# %%
df['Genre'].value_counts() #Hangi türden kaç film var bulalim.
# Out:
# Comedy       164
# Action       146
# Drama         96
# Horror        47
# Thriller      36
# Adventure     29
# Romance       17
# Name: Genre, dtype: int64

# %%
from matplotlib import pyplot as plt #bar grafigi cizmek icin matplotlib kutuphanesini cagiralim.

# %%
df['Genre'].value_counts().plot(kind='barh',alpha=0.5)
plt.show()
